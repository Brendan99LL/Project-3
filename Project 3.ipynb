# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load
raw_file_path = Path("Resources/Conditions_Contributing_to_COVID-19_Deaths__by_State_and_Age__Provisional_2020-2023.csv")

# Read data file and store into Pandas DataFrames
covid_data = pd.read_csv(raw_file_path)
covid_data.head(5)
# Out:
#    Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0  09/24/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  United States
# 1  09/24/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  United States
# 2  09/24/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  United States
# 3  09/24/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  United States
# 4  09/24/2023  01/01/2020  09/23/2023  By Total   NaN    NaN  United States
#
#         Condition Group                Condition ICD10_codes Age Group  \
# 0  Respiratory diseases  Influenza and pneumonia     J09-J18      0-24
# 1  Respiratory diseases  Influenza and pneumonia     J09-J18     25-34
# 2  Respiratory diseases  Influenza and pneumonia     J09-J18     35-44
# 3  Respiratory diseases  Influenza and pneumonia     J09-J18     45-54
# 4  Respiratory diseases  Influenza and pneumonia     J09-J18     55-64
#
#    COVID-19 Deaths  Number of Mentions Flag
# 0           1569.0              1647.0  NaN
# 1           5804.0              6029.0  NaN
# 2          15080.0             15699.0  NaN
# 3          37414.0             38878.0  NaN
# 4          82668.0             85708.0  NaN

# %%
# overview of the covid dataframe
covid_data.columns
# Out:
# Index(['Data As Of', 'Start Date', 'End Date', 'Group', 'Year', 'Month',
#        'State', 'Condition Group', 'Condition', 'ICD10_codes', 'Age Group',
#        'COVID-19 Deaths', 'Number of Mentions', 'Flag'],
#       dtype='object')

# %%
# removing unnecessary columns from the raw dataframe
covid_data = covid_data[["Year", "Group", "State", "Condition Group", "Condition", "Age Group", "COVID-19 Deaths", "Number of Mentions"]]
covid_data.head(5)
# Out:
#    Year     Group          State       Condition Group  \
# 0   NaN  By Total  United States  Respiratory diseases
# 1   NaN  By Total  United States  Respiratory diseases
# 2   NaN  By Total  United States  Respiratory diseases
# 3   NaN  By Total  United States  Respiratory diseases
# 4   NaN  By Total  United States  Respiratory diseases
#
#                  Condition Age Group  COVID-19 Deaths  Number of Mentions
# 0  Influenza and pneumonia      0-24           1569.0              1647.0
# 1  Influenza and pneumonia     25-34           5804.0              6029.0
# 2  Influenza and pneumonia     35-44          15080.0             15699.0
# 3  Influenza and pneumonia     45-54          37414.0             38878.0
# 4  Influenza and pneumonia     55-64          82668.0             85708.0

# %%
# calculate the number of rows with the values for each column
column_value_counts = covid_data.count()
print(column_value_counts)
# Out:
# Year                  608580
# Group                 621000
# State                 621000
# Condition Group       621000
# Condition             621000
# Age Group             621000
# COVID-19 Deaths       437551
# Number of Mentions    443423
# dtype: int64

# %%
# filtering out the rows with "by Years" and "in year 2020 and 2021"
filtered_covid_data = covid_data[(covid_data["Group"] == "By Year") & (covid_data["Year"].isin([2020, 2021]))]
filtered_covid_data
# Out:
#          Year    Group          State       Condition Group  \
# 12420  2020.0  By Year  United States  Respiratory diseases
# 12421  2021.0  By Year  United States  Respiratory diseases
# 12424  2020.0  By Year  United States  Respiratory diseases
# 12425  2021.0  By Year  United States  Respiratory diseases
# 12428  2020.0  By Year  United States  Respiratory diseases
# ...       ...      ...            ...                   ...
# 62089  2021.0  By Year    Puerto Rico              COVID-19
# 62092  2020.0  By Year    Puerto Rico              COVID-19
# 62093  2021.0  By Year    Puerto Rico              COVID-19
# 62096  2020.0  By Year    Puerto Rico              COVID-19
# 62097  2021.0  By Year    Puerto Rico              COVID-19
#
#                      Condition   Age Group  COVID-19 Deaths  \
# 12420  Influenza and pneumonia        0-24            249.0
# 12421  Influenza and pneumonia        0-24            893.0
# 12424  Influenza and pneumonia       25-34           1112.0
# 12425  Influenza and pneumonia       25-34           3708.0
# 12428  Influenza and pneumonia       35-44           3006.0
# ...                        ...         ...              ...
# 62089                 COVID-19         85+            267.0
# 62092                 COVID-19  Not stated              0.0
# 62093                 COVID-19  Not stated              NaN
# 62096                 COVID-19    All Ages           1629.0
# 62097                 COVID-19    All Ages           1645.0
#
#        Number of Mentions
# 12420               256.0
# 12421               933.0
# 12424              1131.0
# 12425              3855.0
# 12428              3069.0
# ...                   ...
# 62089               267.0
# 62092                 0.0
# 62093                 NaN
# 62096              1629.0
# 62097              1645.0
#
# [24840 rows x 8 columns]

# %%
# Checking the dataframe with value counts
column_value_counts = filtered_covid_data.count()
column_value_counts
# Out:
# Year                  24840
# Group                 24840
# State                 24840
# Condition Group       24840
# Condition             24840
# Age Group             24840
# COVID-19 Deaths       19998
# Number of Mentions    20243
# dtype: int64

# %%
# drop the rows have the null values in the column "COVID-19 eaths"
filtered_covid_data = filtered_covid_data.dropna(subset=["COVID-19 Deaths"])
filtered_covid_data
# Out:
#          Year    Group          State       Condition Group  \
# 12420  2020.0  By Year  United States  Respiratory diseases
# 12421  2021.0  By Year  United States  Respiratory diseases
# 12424  2020.0  By Year  United States  Respiratory diseases
# 12425  2021.0  By Year  United States  Respiratory diseases
# 12428  2020.0  By Year  United States  Respiratory diseases
# ...       ...      ...            ...                   ...
# 62088  2020.0  By Year    Puerto Rico              COVID-19
# 62089  2021.0  By Year    Puerto Rico              COVID-19
# 62092  2020.0  By Year    Puerto Rico              COVID-19
# 62096  2020.0  By Year    Puerto Rico              COVID-19
# 62097  2021.0  By Year    Puerto Rico              COVID-19
#
#                      Condition   Age Group  COVID-19 Deaths  \
# 12420  Influenza and pneumonia        0-24            249.0
# 12421  Influenza and pneumonia        0-24            893.0
# 12424  Influenza and pneumonia       25-34           1112.0
# 12425  Influenza and pneumonia       25-34           3708.0
# 12428  Influenza and pneumonia       35-44           3006.0
# ...                        ...         ...              ...
# 62088                 COVID-19         85+            333.0
# 62089                 COVID-19         85+            267.0
# 62092                 COVID-19  Not stated              0.0
# 62096                 COVID-19    All Ages           1629.0
# 62097                 COVID-19    All Ages           1645.0
#
#        Number of Mentions
# 12420               256.0
# 12421               933.0
# 12424              1131.0
# 12425              3855.0
# 12428              3069.0
# ...                   ...
# 62088               333.0
# 62089               267.0
# 62092                 0.0
# 62096              1629.0
# 62097              1645.0
#
# [19998 rows x 8 columns]

# %%
column_value_counts = filtered_covid_data.count()
column_value_counts
# Out:
# Year                  19998
# Group                 19998
# State                 19998
# Condition Group       19998
# Condition             19998
# Age Group             19998
# COVID-19 Deaths       19998
# Number of Mentions    19998
# dtype: int64

# %%
# version_2 - filtered data without using the Age Group (this dataset can be combined with other factors such as medicaid users, TSA travel# by state, etc.
filtered_covid_data_wo_age_group = filtered_covid_data[filtered_covid_data["Age Group"] == "All Ages"]
filtered_covid_data_wo_age_group.head(10)
# Out:
#          Year    Group          State       Condition Group  \
# 12456  2020.0  By Year  United States  Respiratory diseases
# 12457  2021.0  By Year  United States  Respiratory diseases
# 12496  2020.0  By Year  United States  Respiratory diseases
# 12497  2021.0  By Year  United States  Respiratory diseases
# 12536  2020.0  By Year  United States  Respiratory diseases
# 12537  2021.0  By Year  United States  Respiratory diseases
# 12576  2020.0  By Year  United States  Respiratory diseases
# 12577  2021.0  By Year  United States  Respiratory diseases
# 12616  2020.0  By Year  United States  Respiratory diseases
# 12617  2021.0  By Year  United States  Respiratory diseases
#
#                                  Condition Age Group  COVID-19 Deaths  \
# 12456              Influenza and pneumonia  All Ages         168023.0
# 12457              Influenza and pneumonia  All Ages         246574.0
# 12496   Chronic lower respiratory diseases  All Ages          34980.0
# 12497   Chronic lower respiratory diseases  All Ages          38040.0
# 12536  Adult respiratory distress syndrome  All Ages          41717.0
# 12537  Adult respiratory distress syndrome  All Ages          49427.0
# 12576                  Respiratory failure  All Ages         138355.0
# 12577                  Respiratory failure  All Ages         194736.0
# 12616                   Respiratory arrest  All Ages           8152.0
# 12617                   Respiratory arrest  All Ages           9237.0
#
#        Number of Mentions
# 12456            171039.0
# 12457            253846.0
# 12496             36225.0
# 12497             39814.0
# 12536             41717.0
# 12537             49427.0
# 12576            141725.0
# 12577            199932.0
# 12616              8152.0
# 12617              9237.0

# %%
# export both dataframes filtered_covid_data & filtered_covid_data_wo_age_group
filtered_covid_data.to_excel("Resources/filtered_covid_data.xlsx", index=False)
filtered_covid_data_wo_age_group.to_excel("Resources/filtered_covid_data_without_age_group.xlsx", index=False)
